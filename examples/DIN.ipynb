# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Wp-Zhang/HandyRec/blob/master/examples/DIN.ipynb)

# %% [markdown]
# > This notebook runs DIN on MovieLens1M dataset. We'll use YouTubeDNN for generating candidates and DIN for ranking these candidates.
#
# > Only movies with ratings larger than 3 are treated as 'positive' samples for each user. Every last 10 'positive' movies of each user are held out for testing.

# %% [markdown]
# ## Table of Contents:
# * [Prepare data for matching](#section-0)
# * [Train match model and export embeddings](#section-1)
# * [Use Faiss to generate candidates](#section-2)
# * [Train rank model and predict](#section-3)

# %% [markdown]
# **Download dataset and install packages**

# %%
! git clone https://github.com/Wp-Zhang/HandyRec.git
! pip install faiss-cpu
# Out:
# Cloning into 'HandyRec'...
# remote: Enumerating objects: 1500, done.
# remote: Counting objects: 100% (1500/1500), done.
# remote: Compressing objects: 100% (1140/1140), done.
# remote: Total 1500 (delta 561), reused 1165 (delta 309), pack-reused 0
# Receiving objects: 100% (1500/1500), 20.56 MiB | 28.38 MiB/s, done.
# Resolving deltas: 100% (561/561), done.
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 4.1 MB/s
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.7.2

# %%
! wget https://files.grouplens.org/datasets/movielens/ml-1m.zip -O ./ml-1m.zip
! unzip -o ml-1m.zip
# Out:
# --2022-04-07 21:42:11--  https://files.grouplens.org/datasets/movielens/ml-1m.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5917549 (5.6M) [application/zip]
# Saving to: ‘./ml-1m.zip’
#
# ./ml-1m.zip         100%[===================>]   5.64M  20.3MB/s    in 0.3s
#
# 2022-04-07 21:42:12 (20.3 MB/s) - ‘./ml-1m.zip’ saved [5917549/5917549]
#
# Archive:  ml-1m.zip
#    creating: ml-1m/
#   inflating: ml-1m/movies.dat
#   inflating: ml-1m/ratings.dat
#   inflating: ml-1m/README
#   inflating: ml-1m/users.dat

# %% [markdown]
# **Import relative packages**

# %%
import sys
sys.path.append('./HandyRec/')

# %%
from handyrec.dataset.movielens import MovieMatchDataHelper, MovieRankDataHelper
from handyrec.models.match import YouTubeMatchDNN
from handyrec.models.rank import DIN
from handyrec.features import DenseFeature, SparseFeature, SparseSeqFeature, FeatureGroup, EmbdFeatureGroup, FeaturePool
from handyrec.layers.utils import sampledsoftmaxloss
from handyrec.dataset.metrics import map_at_k, recall_at_k
from handyrec.models.utils import search_embedding

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.utils import plot_model
import pandas as pd
import numpy as np
import gc

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
MATCH_EMBEDDING_DIM = 256
RANK_EMBEDDING_DIM = 128
SEQ_LEN = 40
BATCH_SIZE = 2**12
NEPOCH = 50

NEG_NUM = 10
CANDIDATE_NUM = 100

# %% [markdown]
# # 0. Prepare data for ranking<a name="section-0"></a>

# %%
match_dh = MovieMatchDataHelper('./ml-1m/')
data = match_dh.get_clean_data(sparse_features=['gender','age','occupation','zip','year'])

match_user_features = ['user_id','gender','age','occupation','zip']
match_movie_features = [f for f in data['item'].columns if f != 'title']
match_dh.gen_dataset(match_user_features+match_movie_features, data, seq_max_len=SEQ_LEN, negnum=0)
# Out:
# Encode User Sparse Feats: 100%|██████████| 4/4 [00:00<00:00, 153.30it/s]
# Encode Item Sparse Feats: 100%|██████████| 1/1 [00:00<00:00, 193.18it/s]
# Generate train set: 100%|██████████| 6040/6040 [00:05<00:00, 1079.56it/s]
# 100%|██████████| 4/4 [00:00<00:00,  4.31it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.55it/s]

# %%
match_train, match_train_label, match_test, match_test_label = match_dh.load_dataset(match_user_features, match_movie_features)
# Out:
# Load user Features: 100%|██████████| 7/7 [00:00<00:00, 50.92it/s]
# Load movie Features: 100%|██████████| 3/3 [00:00<00:00, 124.09it/s]

# %%
match_feature_dim = match_dh.get_feature_dim(data, match_user_features, match_movie_features, [])

# %% [markdown]
# # 1. Train match model and export embeddings <a name="section-1"></a>

# %%
# * add example_age^2 as showed in the original paper
match_train['example_age_2'] = match_train['example_age']**2
match_test['example_age_2'] = match_test['example_age']**2

# %%
match_user_dense_feats = ['example_age','example_age_2']
match_user_sparse_feats = ['user_id','gender','age','occupation','zip']

# %%
match_item_dense_feats = []
match_item_sparse_feats = [f for f in match_movie_features if f!='genres']
all_item_model_input = {f:np.array(data['item'][f].tolist()) for f in match_movie_features}

# %%
feat_pool1 = FeaturePool()

# %%
match_item_features = [DenseFeature(x) for x in match_item_dense_feats] +\
                [SparseFeature(x, match_feature_dim[x], MATCH_EMBEDDING_DIM) for x in match_item_sparse_feats] +\
                [SparseSeqFeature(SparseFeature('genre_id', 19, MATCH_EMBEDDING_DIM), 'genres',6)]
item_feature_group = EmbdFeatureGroup(
    name='item', 
    id_name='movie_id', 
    features=match_item_features, 
    feature_pool=feat_pool1, 
    value_dict=all_item_model_input,
    embd_dim=MATCH_EMBEDDING_DIM)

# %%
match_user_features = [DenseFeature(x) for x in match_user_dense_feats] +\
                [SparseFeature(x, match_feature_dim[x], MATCH_EMBEDDING_DIM) for x in match_user_sparse_feats] +\
                [SparseSeqFeature(item_feature_group, 'hist_movie_id',SEQ_LEN)]
user_feature_group = FeatureGroup('user', match_user_features, feat_pool1)

# %%
match_model = YouTubeMatchDNN(
    user_feature_group, item_feature_group,
    dnn_hidden_units=(512,256,MATCH_EMBEDDING_DIM), 
    dnn_dropout=0.1,
    dnn_bn=True,
    num_sampled=100
)

# %%
plot_model(match_model)

# %%
match_model.compile(optimizer=tf.keras.optimizers.Adam(lr=5e-4), loss=sampledsoftmaxloss)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='./match_checkpoint/',
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)
history = match_model.fit(match_train, match_train_label,
                            batch_size=BATCH_SIZE, 
                            epochs=NEPOCH,
                            verbose=1,
                            validation_split=0.1,
                            callbacks=[early_stop,checkpoint])
# Out:
# Epoch 1/50
# 207/207 [==============================] - 18s 56ms/step - loss: 3.6127 - val_loss: 3.4918
# Epoch 2/50
# 207/207 [==============================] - 11s 51ms/step - loss: 2.9963 - val_loss: 2.9243
# Epoch 3/50
# 207/207 [==============================] - 11s 51ms/step - loss: 2.7179 - val_loss: 2.6692
# Epoch 4/50
# 207/207 [==============================] - 10s 50ms/step - loss: 2.4975 - val_loss: 2.4930
# Epoch 5/50
# 207/207 [==============================] - 11s 51ms/step - loss: 2.3552 - val_loss: 2.3102
# Epoch 6/50
# 207/207 [==============================] - 10s 50ms/step - loss: 2.2195 - val_loss: 2.1771
# Epoch 7/50
# 207/207 [==============================] - 10s 49ms/step - loss: 2.1314 - val_loss: 2.1858
# Epoch 8/50
# 207/207 [==============================] - 10s 50ms/step - loss: 2.0531 - val_loss: 2.1044
# Epoch 9/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.9637 - val_loss: 2.0031
# Epoch 10/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.9057 - val_loss: 1.9972
# Epoch 11/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.8353 - val_loss: 1.9403
# Epoch 12/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.8182 - val_loss: 1.9387
# Epoch 13/50
# 207/207 [==============================] - 10s 51ms/step - loss: 1.7934 - val_loss: 1.8768
# Epoch 14/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.7307 - val_loss: 1.9597
# Epoch 15/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.6991 - val_loss: 1.8512
# Epoch 16/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.6616 - val_loss: 1.8422
# Epoch 17/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.6413 - val_loss: 1.7819
# Epoch 18/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.5916 - val_loss: 1.7391
# Epoch 19/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.5916 - val_loss: 1.8369
# Epoch 20/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.5918 - val_loss: 1.7297
# Epoch 21/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.5493 - val_loss: 1.8890
# Epoch 22/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.5437 - val_loss: 1.8448
# Epoch 23/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.5246 - val_loss: 1.7569
# Epoch 24/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.4947 - val_loss: 1.8124
# Epoch 25/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.4658 - val_loss: 1.7226
# Epoch 26/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.4648 - val_loss: 1.6812
# Epoch 27/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.4574 - val_loss: 1.7570
# Epoch 28/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.4406 - val_loss: 1.8004
# Epoch 29/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.4180 - val_loss: 1.7289
# Epoch 30/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.4228 - val_loss: 1.7195
# Epoch 31/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.4072 - val_loss: 1.7658
# Epoch 32/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3779 - val_loss: 1.7806
# Epoch 33/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3875 - val_loss: 1.7961
# Epoch 34/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3622 - val_loss: 1.6874
# Epoch 35/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3364 - val_loss: 1.6897
# Epoch 36/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3360 - val_loss: 1.7328
# Epoch 37/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3516 - val_loss: 1.7070
# Epoch 38/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3319 - val_loss: 1.6958
# Epoch 39/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3067 - val_loss: 1.7690
# Epoch 40/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3064 - val_loss: 1.7097
# Epoch 41/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3020 - val_loss: 1.7501
# Epoch 42/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.2832 - val_loss: 1.7762
# Epoch 43/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.3048 - val_loss: 1.7165
# Epoch 44/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.2763 - val_loss: 1.7184
# Epoch 45/50
# 207/207 [==============================] - 10s 50ms/step - loss: 1.2614 - val_loss: 1.6767
# Epoch 46/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.2676 - val_loss: 1.7361
# Epoch 47/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.2549 - val_loss: 1.6861
# Epoch 48/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.2483 - val_loss: 1.7369
# Epoch 49/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.2286 - val_loss: 1.7493
# Epoch 50/50
# 207/207 [==============================] - 10s 49ms/step - loss: 1.2434 - val_loss: 1.7781

# %%
match_model.load_weights('./match_checkpoint/')

# %%
user_embedding_model = Model(inputs=match_model.user_input, outputs=match_model.user_embedding)
item_embedding_model = Model(inputs=match_model.item_input, outputs=match_model.item_embedding)

user_embs = user_embedding_model.predict(match_test, batch_size=2 ** 15)
item_embs = item_embedding_model.predict(all_item_model_input, batch_size=2 ** 15)

print(user_embs.shape)
print(item_embs.shape)
# Out:
# (6040, 256)
# (3883, 256)

# %% [markdown]
# # 2. Use Faiss to generate candidates <a name="section-2"></a>

# %% [markdown]
# ## Test match model

# %%
candidates = search_embedding(
    MATCH_EMBEDDING_DIM, 
    item_embs, 
    user_embs,
    data['item']['movie_id'].values,
    CANDIDATE_NUM)

# %%
map_at_k(match_test_label, candidates, k=10)
# Out:
# 0.03154330915589194

# %%
recall_at_k(match_test_label, candidates, k=10)
# Out:
# 0.07887417218543046

# %%
recall_at_k(match_test_label, candidates, k=100)
# Out:
# 0.4335927152317881

# %% [markdown]
# ## Prepare data for ranking

# %%
test_user_embs = user_embedding_model.predict(match_test, batch_size=2 ** 15)
test_candidates = search_embedding(
    MATCH_EMBEDDING_DIM, 
    item_embs, 
    test_user_embs,
    data['item']['movie_id'].values,
    CANDIDATE_NUM)

test_candidates = {
    match_test['user_id'][i] : test_candidates[i]
    for i in range(test_candidates.shape[0])
}

# %%
del user_embs, item_embs, match_train, match_train_label, test_user_embs
gc.collect()
# Out:
# 4007

# %%
rank_dh = MovieRankDataHelper('./ml-1m/')
rank_user_features = ['user_id','gender','age','occupation','zip']
rank_movie_features = [f for f in data['item'].columns if f != 'title']

rank_dh.gen_dataset(rank_user_features+rank_movie_features, data, test_candidates, seq_max_len=SEQ_LEN, negnum=NEG_NUM)
# Out:
# Generate train set: 100%|██████████| 6040/6040 [00:41<00:00, 144.29it/s]
# 100%|██████████| 4/4 [00:05<00:00,  1.30s/it]
# 100%|██████████| 2/2 [00:12<00:00,  6.30s/it]

# %%
rank_train, rank_train_label, rank_test = rank_dh.load_dataset(rank_user_features, rank_movie_features)
# Out:
# Load user Features: 100%|██████████| 8/8 [00:01<00:00,  5.10it/s]
# Load movie Features: 100%|██████████| 3/3 [00:00<00:00, 12.20it/s]

# %%
rank_feature_dim = rank_dh.get_feature_dim(data, rank_user_features, rank_movie_features, [])

# %% [markdown]
# # 3. Train rank model and predict <a name="section-3"></a>

# %%
rank_user_dense_feats = []
rank_user_sparse_feats = ['user_id','gender','age','occupation', 'zip']
rank_item_dense_feats = []
rank_item_sparse_feats = [f for f in rank_movie_features if f!='genres']

# %%
feat_pool2 = FeaturePool()

# %%
all_item_model_input = {f:np.array(data['item'][f].tolist()) for f in match_movie_features}
rank_item_feats = [SparseFeature(x, rank_feature_dim[x], RANK_EMBEDDING_DIM) for x in rank_item_sparse_feats] +\
                [DenseFeature(x) for x in rank_item_dense_feats] +\
                [SparseSeqFeature(SparseFeature('genre_id', 19, RANK_EMBEDDING_DIM), 'genres',6)]
item_feature_group = EmbdFeatureGroup(
    name='item', 
    id_name='movie_id', 
    features=rank_item_feats, 
    feature_pool=feat_pool2, 
    value_dict=all_item_model_input,
    embd_dim=RANK_EMBEDDING_DIM
)

# %%
rank_item_seq_features = [SparseSeqFeature(item_feature_group, 'hist_movie_id', SEQ_LEN)]
item_seq_feat_group = FeatureGroup('fm', rank_item_seq_features, feat_pool2)

# %%
rank_other_feats = [DenseFeature(x) for x in rank_user_dense_feats] +\
                    [SparseFeature(x, rank_feature_dim[x], RANK_EMBEDDING_DIM) for x in rank_user_sparse_feats]
other_feature_group = FeatureGroup('dnn', rank_other_feats, feat_pool2)

# %%
rank_model = DIN(
    item_seq_feat_group, other_feature_group, 
    dnn_hidden_units=(256,128,1), dnn_activation='dice', dnn_dropout=0.2, l2_dnn=0.2, dnn_bn=True,
    lau_dnn_hidden_units=(36,1), lau_dnn_activation='dice', lau_dnn_dropout=0., lau_l2_dnn=0.2, lau_dnn_bn=False,
)

# %%
plot_model(rank_model)

# %%
rank_model.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4), loss=binary_crossentropy)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='./rank_checkpoint/',
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True)
history = rank_model.fit(rank_train, rank_train_label,
                    batch_size=BATCH_SIZE*2, 
                    epochs=NEPOCH,
                    verbose=1,
                    validation_split=0.1,
                    callbacks=[early_stop,checkpoint])
# Out:
# Epoch 1/50
# 1136/1136 [==============================] - 347s 300ms/step - loss: 209.5931 - val_loss: 120.0859
# Epoch 2/50
# 1136/1136 [==============================] - 339s 299ms/step - loss: 80.1565 - val_loss: 50.5805
# Epoch 3/50
# 1136/1136 [==============================] - 339s 299ms/step - loss: 33.9519 - val_loss: 21.8515
# Epoch 4/50
# 1136/1136 [==============================] - 340s 299ms/step - loss: 14.5322 - val_loss: 9.0186
# Epoch 5/50
# 1136/1136 [==============================] - 339s 299ms/step - loss: 5.9129 - val_loss: 3.6151
# Epoch 6/50
# 1136/1136 [==============================] - 340s 299ms/step - loss: 3.0424 - val_loss: 2.2456
# Epoch 7/50
# 1136/1136 [==============================] - 341s 300ms/step - loss: 1.8221 - val_loss: 1.4297
# Epoch 8/50
# 1136/1136 [==============================] - 341s 300ms/step - loss: 1.4201 - val_loss: 1.2703
# Epoch 9/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 1.2394 - val_loss: 1.7338
# Epoch 10/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 1.2134 - val_loss: 1.0188
# Epoch 11/50
# 1136/1136 [==============================] - 339s 299ms/step - loss: 0.9753 - val_loss: 0.8772
# Epoch 12/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 0.9159 - val_loss: 0.8666
# Epoch 13/50
# 1136/1136 [==============================] - 341s 300ms/step - loss: 0.8872 - val_loss: 0.8190
# Epoch 14/50
# 1136/1136 [==============================] - 340s 299ms/step - loss: 0.9067 - val_loss: 1.2723
# Epoch 15/50
# 1136/1136 [==============================] - 341s 300ms/step - loss: 0.7134 - val_loss: 0.3602
# Epoch 16/50
# 1136/1136 [==============================] - 343s 302ms/step - loss: 0.5967 - val_loss: 0.3437
# Epoch 17/50
# 1136/1136 [==============================] - 341s 300ms/step - loss: 0.5503 - val_loss: 0.3374
# Epoch 18/50
# 1136/1136 [==============================] - 339s 299ms/step - loss: 0.5449 - val_loss: 0.3406
# Epoch 19/50
# 1136/1136 [==============================] - 339s 298ms/step - loss: 0.5274 - val_loss: 0.3077
# Epoch 20/50
# 1136/1136 [==============================] - 339s 299ms/step - loss: 0.5247 - val_loss: 0.3075
# Epoch 21/50
# 1136/1136 [==============================] - 340s 299ms/step - loss: 0.5252 - val_loss: 0.3072
# Epoch 22/50
# 1136/1136 [==============================] - 341s 300ms/step - loss: 0.5244 - val_loss: 0.3072
# Epoch 23/50
# 1136/1136 [==============================] - 341s 300ms/step - loss: 0.5243 - val_loss: 0.3071
# Epoch 24/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 0.5242 - val_loss: 0.3071
# Epoch 25/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 0.5243 - val_loss: 0.3071
# Epoch 26/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 0.5235 - val_loss: 0.3071
# Epoch 27/50
# 1136/1136 [==============================] - 340s 299ms/step - loss: 0.5253 - val_loss: 0.3069
# Epoch 28/50
# 1136/1136 [==============================] - 340s 299ms/step - loss: 0.5242 - val_loss: 0.3070
# Epoch 29/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 0.5240 - val_loss: 0.3071
# Epoch 30/50
# 1136/1136 [==============================] - 340s 300ms/step - loss: 0.5243 - val_loss: 0.3071
# Epoch 31/50
# 1136/1136 [==============================] - 340s 299ms/step - loss: 0.5238 - val_loss: 0.3070

# %%
rank_model.load_weights('./rank_checkpoint/')

# %%
del rank_train
gc.collect()
# Out:
# 2283

# %%
pred = rank_model.predict(rank_test, batch_size=BATCH_SIZE*2)

# %%
pred_df = pd.DataFrame(columns=['user_id','movie_id','pred'])
pred_df['user_id'] = rank_test['user_id']
pred_df['movie_id'] = rank_test['movie_id']
pred_df['pred'] = pred

pred_df = pred_df.sort_values(by=['user_id','pred'], ascending=False).reset_index(drop=True)
pred_df = pred_df.groupby('user_id')['movie_id'].apply(list).reset_index()

# %%
test_label_df = pd.DataFrame(columns=['user_id','label'])
test_label_df['user_id'] = match_test['user_id']
test_label_df['label'] = match_test_label.tolist()

# %%
test_label_df = pd.merge(test_label_df, pred_df, on=['user_id'], how='left')

# %%
map_at_k(test_label_df['label'], test_label_df['movie_id'], k=10)
# Out:
# 0.03154330915589194

# %%
recall_at_k(test_label_df['label'], test_label_df['movie_id'], k=10)
# Out:
# 0.07887417218543046

# %%
recall_at_k(test_label_df['label'], test_label_df['movie_id'], k=100)
# Out:
# 0.4335927152317881
